# %%
import numpy as np

import awkward as ak
import uproot

# %%
f16 = uproot.open(
    "../../../../SUEPNano_Nov2024/CMSSW_10_6_44/src/PhysicsTools/SUEPNano/test/nano_2016_numEvent50000.root"
)
f17 = uproot.open(
    "../../../../SUEPNano_Nov2024/CMSSW_10_6_44/src/PhysicsTools/SUEPNano/test/nano_2017_numEvent50000.root"
)
f18 = uproot.open(
    "../../../../SUEPNano_Nov2024/CMSSW_10_6_44/src/PhysicsTools/SUEPNano/test/nano_2018_numEvent50000.root"
)

# %%
evts16 = f16["Events"]
evts17 = f17["Events"]
evts18 = f18["Events"]

# %%
np.mean(evts16["PV_npvsGood"].array())
# Out:
# 21.538543897216275

# %%
np.mean(evts17["PV_npvsGood"].array())
# Out:
# 28.546576879910212

# %%
np.mean(evts18["PV_npvsGood"].array())
# Out:
# 22.54343329886246

# %%
2016 NanoAOD file events: 1868

2017 NanoAOD file events: 2673

events 1934

# %%
1934 / 1868
# Out:
# 1.0353319057815846

# %%
22.54343329886246 / 21.538543897216275
# Out:
# 1.0466554009612534

# %%
2673 / 1868
# Out:
# 1.4309421841541756

# %%
28.546576879910212 / 21.538543897216275
# Out:
# 1.325371715754642
